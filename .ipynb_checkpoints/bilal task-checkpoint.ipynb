# %%
import pandas as pd

# %%
dff=pd.read_csv("Book1.csv")

# %%
dff
# Out:
#       Order Date         Category Sub_Category  \
# 0      11/8/2016        Furniture    Bookcases
# 1      11/8/2016        Furniture       Chairs
# 2      6/12/2016  Office Supplies       Labels
# 3     10/11/2015        Furniture       Tables
# 4     10/11/2015  Office Supplies      Storage
# ...          ...              ...          ...
# 9989   1/21/2014        Furniture  Furnishings
# 9990   2/26/2017        Furniture  Furnishings
# 9991   2/26/2017       Technology       Phones
# 9992   2/26/2017  Office Supplies        Paper
# 9993    5/4/2017  Office Supplies   Appliances
#
#                                            Product_Name     Sales
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775
# ...

# %%
dff['Order Date'] = pd.to_datetime(dff['Order Date'])
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    9994 non-null   datetime64[ns]
#  1   Category      9994 non-null   object
#  2   Sub_Category  9994 non-null   object
#  3   Product_Name  9994 non-null   object
#  4   Sales         9994 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 390.5+ KB

# %%
from sklearn import preprocessing

# %%
cat_col=['Order Date','Category', 'Sub_Category', 'Product_Name']
labelEncoder = preprocessing.LabelEncoder()   
mapping_dict ={} 
for col in cat_col: 
    dff[col] = labelEncoder.fit_transform(dff[col]) 
    le_name_mapping = dict(zip(labelEncoder.classes_,labelEncoder.transform(labelEncoder.classes_))) 
    mapping_dict[col]= le_name_mapping 
    print(mapping_dict)
# Out:
# {'Order Date': {numpy.datetime64('2014-01-03T00:00:00.000000000'): 0, numpy.datetime64('2014-01-04T00:00:00.000000000'): 1, numpy.datetime64('2014-01-05T00:00:00.000000000'): 2, numpy.datetime64('2014-01-06T00:00:00.000000000'): 3, numpy.datetime64('2014-01-07T00:00:00.000000000'): 4, numpy.datetime64('2014-01-09T00:00:00.000000000'): 5, numpy.datetime64('2014-01-10T00:00:00.000000000'): 6, numpy.datetime64('2014-01-11T00:00:00.000000000'): 7, numpy.datetime64('2014-01-13T00:00:00.000000000'): 8, numpy.datetime64('2014-01-14T00:00:00.000000000'): 9, numpy.datetime64('2014-01-15T00:00:00.000000000'): 10, numpy.datetime64('2014-01-16T00:00:00.000000000'): 11, numpy.datetime64('2014-01-18T00:00:00.000000000'): 12, numpy.datetime64('2014-01-19T00:00:00.000000000'): 13, numpy.datetime64('2014-01-20T00:00:00.000000000'): 14, numpy.datetime64('2014-01-21T00:00:00.000000000'): 15, numpy.datetime64('2014-01-23T00:00:00.000000000'): 16, numpy.datetime64('2014-01-26T00:00:00.000000000'): 17, nu
# ...

# %%
X = dff.drop('Sales',axis=1) 
# features
y = dff['Sales']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([  72.0478,   48.456 ,  166.0302, ..., 1871.8242,  224.242 ,
#           8.9396])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.44582513147911484

# %%
X_test
# Out:
#       Order Date  Category  Sub_Category  Product_Name
# 7933        1108         1             7          1493
# 8657         202         1             1           821
# 9599         376         1             1            79
# 799          561         0             5          1450
# 3813         540         1            10           182
# ...          ...       ...           ...           ...
# 4162         350         1            10           182
# 9302         379         1             2          1157
# 4860         903         1             3           686
# 3980         297         1             1           305
# 4995         251         1             3            61
#
# [2999 rows x 4 columns]

# %%
X
# Out:
#       Order Date  Category  Sub_Category  Product_Name
# 0            864         0             4           386
# 1            864         0             5           839
# 2            732         1            10          1433
# 3            519         0            16           366
# 4            519         1            14           573
# ...          ...       ...           ...           ...
# 9989          15         0             9          1586
# 9990         956         0             9          1535
# 9991         956         2            13            47
# 9992         956         1            12           929
# 9993        1016         1             1            54
#
# [9994 rows x 4 columns]

# %%
regressor.predict([['867','0','13','47']])
# Out:
# array([505.41965])

# %%
import matplotlib.pyplot as plt
plt.plot(dff['Order Date'])
plt.plot(y_pred)
plt.xlabel(' Order Date')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
pred_y_df=pd.DataFrame({'Actual Value':y_test,'Predict value':y_pred, 'Diffrence': y_test-y_pred})
pred_y_df[0:20]
# Out:
#       Actual Value  Predict value  Diffrence
# 7933       23.3600        72.0478   -48.6878
# 8657       22.6600        48.4560   -25.7960
# 9599       35.2080       166.0302  -130.8222
# 799       283.9200       222.4770    61.4430
# 3813       19.8240        12.9930     6.8310
# 8088       39.9200        25.4470    14.4730
# 9366       68.4800        36.7600    31.7200
# 9403     1591.0200       585.9722  1005.0478
# 4071      156.3728       343.4496  -187.0768
# 7583     3499.9300       579.1468  2920.7832
# 1085     4899.9300      3074.4643  1825.4657
# 1540      242.4800        11.4951   230.9849
# 2661       79.9600       151.8304   -71.8704
# 3299       50.9970       970.2657  -919.2687
# 2731      107.5300       131.4570   -23.9270
# 3017       22.6080        52.8620   -30.2540
# 1091      120.1500        59.8204    60.3296
# 2617      121.6800        16.9389   104.7411
# 9520       93.0200       221.1536  -128.1336
# 8780       55.3280       118.7224   -63.3944

# %%
X_test
# Out:
#       Order Date  Category  Sub_Category  Product_Name
# 7933        1108         1             7          1493
# 8657         202         1             1           821
# 9599         376         1             1            79
# 799          561         0             5          1450
# 3813         540         1            10           182
# ...          ...       ...           ...           ...
# 4162         350         1            10           182
# 9302         379         1             2          1157
# 4860         903         1             3           686
# 3980         297         1             1           305
# 4995         251         1             3            61
#
# [2999 rows x 4 columns]

# %%
dff.tail()
# Out:
#       Order Date  Category  Sub_Category  Product_Name    Sales
# 9989          15         0             9          1586   25.248
# 9990         956         0             9          1535   91.960
# 9991         956         2            13            47  258.576
# 9992         956         1            12           929   29.600
# 9993        1016         1             1            54  243.160
